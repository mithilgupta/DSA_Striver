# %% [markdown]
# # LL Basics - Revision

# %%
class Node:
    def __init__(self,data):
        self.val = data
        self.next = None


class LinkedList:
    def __init__(self):
        self.head = None


    def append(self,data):

        node = Node(data)

        if self.head == None:
            self.head = node
            self.head.next = None


        else:
            curr = self.head
            while curr.next is not None:
                curr = curr.next

            curr.next = node


    def __str__(self):
        temp_node = self.head
        result = ''
        cnt = 0
        while temp_node is not None and cnt<30:
            result += str(temp_node.val)
            if temp_node.next is not None:
                result += ' -> '
            temp_node = temp_node.next
            cnt +=1
        return result


    def palindrome(self):

        slow = self.head
        fast = self.head

        while fast is not None and fast.next is not None and fast.next.next is not None:
            slow = slow.next
            fast = fast.next.next

        # Storing the next chain in a variable
        new_head = slow.next
        # De Linking
        slow.next = None

        # Getting the reversed second half of the list:
        right = self.reverse(new_head)
        left = self.head

        while right is not None and left is not None:
            # print(left.val, right.val)

            if left.val != right.val:
                return False

            left = left.next
            right = right.next

        return True
        
        

    def reverse(self, head):
        prev = None
        while head is not None:
          next = head.next
          head.next = prev
          prev = head
          head = next
        return prev


    def reorder(self):

        slow = self.head
        fast = self.head

        while fast is not None and fast.next is not None and fast.next.next is not None:
            slow = slow.next
            fast = fast.next.next

        # Storing the next chain in a variable
        new_head = slow.next
        # De Linking
        slow.next = None

        # Getting the reversed second half of the list:
        right = self.reverse(new_head)
        left = self.head

        while left is not None and right is not None:


            # Storing the next element temporarily -could be Node or None
            left_next = left.next
            right_next = right.next

            # Adding the new element
            left.next = right
            right.next = left_next

            left = left_next
            right = right_next


        # After the loop, left ja chuka hai aage.
        # Reinitialize krna pdega head.


    def reverse_k(self,k):
        if k <= 1 or self.head is None:
            return head

        curr = self.head
        prev = None

        while True:
            last_node_of_previous_part = previous
            last_node_of_sub_list = current

            next = None 

            i = 0

# %%
ll = LinkedList()
ll.append(1)
ll.append(2)
ll.append(3)
ll.append(4)
ll.append(5)
# ll.append(3)
ll.append(6)
ll.append(7)

print(ll)
########################
# ll.reorder()
# print(ll)

########################
# Out:
# 1 -> 2 -> 3 -> 4 -> 5 -> 6 -> 7

# %%
16//10
# Out:
# 1

# %%
16%10
# Out:
# 6
