# %%
import collections

# %%
class Node:
    def __init__(self,data):
        self.val = data
        self.left = None
        self.right = None


class BinaryTree:
    def __init__(self):
        self.root = None


    def preOrderTraversal(self, node):

        if self.root is None:
            return None

        else:
            print(self.root.val)
            self.preOrderTraversal(self.root.left)
            self.preOrderTraversal(self.root.right)


    def append(self, new_node):
        # node = Node(data)
        
        if self.root == None:
            self.root = new_node

    def display(self):

        curr = self.root

        print(curr.val)
        print(curr.left.val)
        print(curr.right.val)

# %%
tree = BinaryTree()
one = Node(1)
# tree.append(one)

two = Node(2)
three = Node(3)
four = Node(4)
five = Node(5)
six = Node(6)
seven = Node(7)
eight = Node(8)
nine = Node(9)

tree.append(five)
five.left = two
five.right = three

two.left = one
two.right = four

four.left =six
four.right =eight

# %%
def pre_order(node):
    if node is None:
        return None

    else:
        print ( node.val)
        
        pre_order(node.left)
        pre_order(node.right)

def path_exists(arr, root):
    arr.reverse()

    curr_node = root

    while len(arr)>0:
        curr_val = arr.pop()

        if curr_val == curr_node.val:

# %%
path_exists([5,2,4], five)
# Out:
# 5
# 2
# 1
# 4
# 6
# 8
# 3
