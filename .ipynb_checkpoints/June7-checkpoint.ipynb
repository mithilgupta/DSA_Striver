# %%
# Create a Node Class
class Node:
    def __init__(self, value):
        self.val   = value
        self.next = None
        
# Create a LinkedList Class 
class LinkedList:
    def __init__(self):
        self.head = None

    # insert at beginning:
    def push(self, data):
        temp_node = Node(data)

        if self.head is None:
            temp_node.next = None
            self.head = temp_node
        else:
            temp_node.next = self.head
            self.head = temp_node


    def __str__(self):
        temp_node = self.head
        result = ''
        cnt = 0
        while temp_node is not None and cnt<30:
            result += str(temp_node.val)
            if temp_node.next is not None:
                result += ' -> '
            temp_node = temp_node.next
            cnt +=1
        return result


    def hasCycle(self):

        if self.head.next == None:
            return False

        slow = self.head
        fast = self.head.next

        while fast is not None or fast.next.next is not None :

            if slow == fast:
                return True
            else:
                pass
                
            slow = slow.next
            fast = fast.next.next


        return False


    def findMiddle(self):

        slow, fast = self.head, self.head

        while fast is not None and fast.next is not None:
            slow = slow.next
            fast = fast.next.next


        return slow.val


    # Function to create a cycle in the LL
    def createcycle(self, val):

        temp_node = Node(val)

        node = self.head

        temp_node.next = node.next.next

        while node.next is not None:
            node = node.next

        # print(node.val)


        node.next = temp_node

        
    # Function to finf the start of the cycle. In our example, it should be 'c'
    # I don't know how to proceed with this approach. So this becomes essentially finding the Length of the Cycle.
    def findCycleStart(self):

        slow = self.head
        fast = self.head

        while fast is not None and fast.next is not None:
            fast = fast.next.next
            slow = slow.next

            if fast == slow:
                break


        # print(fast.val,slow.val)

        meet_pt = slow

        #variable to get the length of the cycle
        cnt = 0

        # I had to move the slow to next value so my 
        #while loop doesn't break because the initial condition of meet_pt = slow
        slow = slow.next
        while slow != meet_pt:
            slow = slow.next
            cnt +=1

        print('length of the cycle = ', str(cnt+1))


        
    # I have an approach for N^2 time complexity. Using 2 while loops.
    def findCycleStart(self):  

        # slow = self.head
        fast = self.head

        cnt = 0

        while fast is not None and cnt < 30:
            fast = fast.next
            cnt +=1
            # print(fast.val)

            slow = self.head

            # print("slow:")
            while slow != fast:
                # print(slow.val)
                if slow.val == fast.next.val:
                    return slow.val
                slow = slow.next


            # print("---------------------")
        
        


    # Reverse a LL
    def reverse(self):

        prev = None
        current = self.head
        next = None


        while current is not None:
            ncurrent.next

# %%
# create a new linked list
ll = LinkedList()
 
# add nodes to the linked list


# ll.push('h')
# ll.push('g')
ll.push('f')
ll.push('e')
ll.push('d')
ll.push('c')
ll.push('b')
ll.push('a')
ll.createcycle('g')
# ll.insert(1,3)
print(ll)
print("----------------")
# ll.findMiddle()

# Detect cycle : WORKING
ll.hasCycle()

# Finding the Start of the Cycle:
ll.findCycleStart()
# Out:
# a -> b -> c -> d -> e -> f -> g -> c -> d -> e -> f -> g -> c -> d -> e -> f -> g -> c -> d -> e -> f -> g -> c -> d -> e -> f -> g -> c -> d -> e ->
# ----------------
# 'c'

# %%
def get_digit_sq(num):
    ans = 0
    num = str(num)
    for i in range(len(num)):
        # print(num[i])
        ans += int(num[i])*int(num[i])

    return ans
        

# Happy number
# This Brute Force approach with List works with 2 loops.
def find(num):

    ll = []

    # Initializing with the first value
    dig_sq = get_digit_sq(num)
    ll.append(dig_sq)

    while ll[-1] != 1:
        new_dig_sq = get_digit_sq(ll[-1])
    
        for i in range(len(ll)):
            if ll[i] == new_dig_sq:
                return False
                
        ll.append(new_dig_sq)


    return True


# I tried doing it with Slow and Fast Pointer.
# But I got stuck in 2 places:
# 1. Initializing slow and Fast, because how do I counter initial While COndition if both are HEAD.
# 2. The values of slow and fast are not changing with each iteration (function call to get_digit_sq()) -> Does this need recursion??
    
def find2(num):
    slow = num
    fast = get_digit_sq(num)
    cnt = 0

    while slow != fast and cnt < 30:
        fast = get_digit_sq(get_digit_sq(num))
        slow = get_digit_sq(num)
        cnt +=1


        print(slow, fast)

# %%
find2(23)
# Out:
# 13 10
# 13 10
# 13 10
# 13 10
# 13 10
# 13 10
# 13 10
# 13 10
# 13 10
# 13 10
# 13 10
# 13 10
# 13 10
# 13 10
# 13 10
# 13 10
# 13 10
# 13 10
# 13 10
# 13 10
# 13 10
# 13 10
# 13 10
# 13 10
# 13 10
# 13 10
# 13 10
# 13 10
# 13 10
# 13 10
